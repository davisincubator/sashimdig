# %%
from os import getcwd
from os import listdir
from os.path import isfile, join, isdir

mypath = getcwd()

trainPath = join(mypath,'train')
groupNames = [f for f in listdir(trainPath) if isdir(join(trainPath, f))]


print(groupNames)
# Out:
# ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']

# %%
import numpy as np
import pandas as pd

groupData = pd.DataFrame ({'group': groupNames})
groupData.test = 'test'

# %%
groupData.ix[0,'foo'] = 99
groupData
# Out:
#    group  foo  (foo, 1)
# 0    ALB   99         0
# 1    BET    9         0
# 2    DOL    9         0
# 3    LAG    9         0
# 4    NoF    9         0
# 5  OTHER    9         0
# 6  SHARK    9         0
# 7    YFT    9         0

# %%
for idx,g in enumerate(groupNames):
    fileNames = [f for f in listdir(join(trainPath,g)) if isfile(join(trainPath,g, f))]
    print(len(fileNames))

    groupData.ix[idx,'bar'] = int(len(fileNames))
    

    
groupData
# Out:
# 1719
# 200
# 117
# 67
# 465
# 299
# 176
# 734
#    group   foo  (foo, 1)     bar
# 0    ALB  1719         0  1719.0
# 1    BET   200         0   200.0
# 2    DOL   117         0   117.0
# 3    LAG    67         0    67.0
# 4    NoF   465         0   465.0
# 5  OTHER   299         0   299.0
# 6  SHARK   176         0   176.0
# 7    YFT   734         0   734.0

# %%
import matplotlib.pyplot as plt
import skimage
from skimage import io
camera = io.imread(join(testPath,testPicPaths[0]))


plt.figure(figsize=(5, 5))
plt.imshow(camera, cmap='gray', interpolation='nearest')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
camera.shape
# Out:
# (720, 1280, 3)

# %%
import pandas as pd
import numpy  as np

# %%
foo = len(fileNames)
# Out:
# 734
